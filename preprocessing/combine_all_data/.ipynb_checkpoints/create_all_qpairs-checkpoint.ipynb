# %%
# 添加搜索是路径
import sys
sys.path.insert(0, '/root/mounted/projects/qpair/')

# %%
# 加载全局配置
from config import *

# %%
# 导入模块
import pandas as pd
import pickle
import numpy as np
from matplotlib import pyplot as plt

# %%
train_csv_df = pd.read_csv(TRAIN_CSV)
kn_csv_df = pd.read_csv(KN_CSV)

# %%
train_csv_df.head()
# Out:
#        qid   cid  label
# 0  Q330857  C081      1
# 1  Q330857  C058      0
# 2  Q330857  C091      0
# 3  Q330857  C087      0
# 4  Q330857  C083      0

# %%
pd.DataFrame.pivot?

# %%
train_csv_df_wide = train_csv_df.pivot(index='cid', columns='qid', values='label')
train_csv_df_wide
# Out:
# qid   Q000087  Q000133  Q000138  Q000167  Q000190  Q000443  Q000632  Q000794  \
# cid
# C001      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# C003      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# C004      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# C005      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# C006      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# C007      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# C008      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# C015      NaN      NaN      NaN      0.0      NaN      NaN      NaN      NaN
# C016      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# C017      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# C019      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ...

# %%
qvsc = pd.notna(train_csv_df_wide).sum()
qvsc
# Out:
# qid
# Q000087    5
# Q000133    5
# Q000138    4
# Q000167    5
# Q000190    5
# Q000443    5
# Q000632    5
# Q000794    5
# Q000799    5
# Q000849    2
# Q000852    4
# Q000867    2
# Q000916    5
# Q000930    5
# Q001076    5
# Q001152    5
# Q001226    4
# Q001256    2
# Q001324    5
# Q001471    5
# Q001481    3
# Q001506    5
# Q001519    4
# Q001529    2
# Q001543    4
# Q001569    5
# Q001628    5
# Q001653    5
# Q001663    5
# Q001697    3
#           ..
# Q727207    4
# Q727321    5
# Q727553    3
# Q727674    5
# Q727682    5
# Q727708    5
# Q727734    5
# Q727815    4
# Q727845    3
# Q727851    5
# Q727858    4
# Q727914    4
# Q727970    5
# Q728013    4
# Q728063    5
# Q728095    5
# Q728112    4
# Q728206    5
# Q728223    5
# Q728346    5
# Q728477    4
# Q728593    5
# Q728715    5
# Q728719    5
# Q728764    3
# Q728891    5
# Q728943    5
# Q728995    5
# Q729049    5
# Q729070    5
# Length: 11447, dtype: int64

# %%
qvsc.max(), qvsc.min(), qvsc.mean()
# Out:
# (5, 2, 4.445182143793134)

# %%
qeqc = train_csv_df_wide == 1
qeqc
# Out:
# qid   Q000087  Q000133  Q000138  Q000167  Q000190  Q000443  Q000632  Q000794  \
# cid
# C001    False    False    False    False    False    False    False    False
# C003    False    False    False    False    False    False    False    False
# C004    False    False    False    False    False    False    False    False
# C005    False    False    False    False    False    False    False    False
# C006    False    False    False    False    False    False    False    False
# C007    False    False    False    False    False    False    False    False
# C008    False    False    False    False    False    False    False    False
# C015    False    False    False    False    False    False    False    False
# C016    False    False    False    False    False    False    False    False
# C017    False    False    False    False    False    False    False    False
# C019    False    False    False    False    False    False    False    False
# ...

# %%
qeqcnum = qeqc.sum()
qeqcnum
# Out:
# qid
# Q000087    1
# Q000133    1
# Q000138    1
# Q000167    1
# Q000190    1
# Q000443    1
# Q000632    1
# Q000794    1
# Q000799    1
# Q000849    1
# Q000852    1
# Q000867    1
# Q000916    1
# Q000930    1
# Q001076    1
# Q001152    1
# Q001226    1
# Q001256    1
# Q001324    1
# Q001471    1
# Q001481    1
# Q001506    1
# Q001519    1
# Q001529    1
# Q001543    1
# Q001569    1
# Q001628    1
# Q001653    1
# Q001663    1
# Q001697    1
#           ..
# Q727207    1
# Q727321    1
# Q727553    1
# Q727674    1
# Q727682    1
# Q727708    1
# Q727734    1
# Q727815    1
# Q727845    1
# Q727851    1
# Q727858    1
# Q727914    1
# Q727970    0
# Q728013    1
# Q728063    1
# Q728095    1
# Q728112    1
# Q728206    1
# Q728223    1
# Q728346    1
# Q728477    1
# Q728593    1
# Q728715    1
# Q728719    1
# Q728764    1
# Q728891    1
# Q728943    0
# Q728995    0
# Q729049    1
# Q729070    1
# Length: 11447, dtype: int64

# %%
qeqcnum.max(), qeqcnum.min(),qeqcnum.mean(), qeqcnum.sum()
# Out:
# (1, 0, 0.9442648728924609, 10809)

# %%
qneqc = train_csv_df_wide == 0
qneqc
# Out:
# qid   Q000087  Q000133  Q000138  Q000167  Q000190  Q000443  Q000632  Q000794  \
# cid
# C001    False    False    False    False    False    False    False    False
# C003    False    False    False    False    False    False    False    False
# C004    False    False    False    False    False    False    False    False
# C005    False    False    False    False    False    False    False    False
# C006    False    False    False    False    False    False    False    False
# C007    False    False    False    False    False    False    False    False
# C008    False    False    False    False    False    False    False    False
# C015    False    False    False     True    False    False    False    False
# C016    False    False    False    False    False    False    False    False
# C017    False    False    False    False    False    False    False    False
# C019    False    False    False    False    False    False    False    False
# ...

# %%
qneqcnum = qneqc.sum()
qneqcnum
# Out:
# qid
# Q000087    4
# Q000133    4
# Q000138    3
# Q000167    4
# Q000190    4
# Q000443    4
# Q000632    4
# Q000794    4
# Q000799    4
# Q000849    1
# Q000852    3
# Q000867    1
# Q000916    4
# Q000930    4
# Q001076    4
# Q001152    4
# Q001226    3
# Q001256    1
# Q001324    4
# Q001471    4
# Q001481    2
# Q001506    4
# Q001519    3
# Q001529    1
# Q001543    3
# Q001569    4
# Q001628    4
# Q001653    4
# Q001663    4
# Q001697    2
#           ..
# Q727207    3
# Q727321    4
# Q727553    2
# Q727674    4
# Q727682    4
# Q727708    4
# Q727734    4
# Q727815    3
# Q727845    2
# Q727851    4
# Q727858    3
# Q727914    3
# Q727970    5
# Q728013    3
# Q728063    4
# Q728095    4
# Q728112    3
# Q728206    4
# Q728223    4
# Q728346    4
# Q728477    3
# Q728593    4
# Q728715    4
# Q728719    4
# Q728764    2
# Q728891    4
# Q728943    5
# Q728995    5
# Q729049    4
# Q729070    4
# Length: 11447, dtype: int64

# %%
qneqcnum.max(), qneqcnum.min(),qneqcnum.mean(),(qneqcnum > 0).sum()
# Out:
# (5, 1, 3.500917270900673, 11447)

# %% [markdown]
# 上面的观察说明在train中不存在冲突的情况
# 有超过90%的问题都给标记出了与之意思相同的知识库类别
# 在train中，给每个问题都标记出了与之意思不一样的类别，但是只给每个问题标记了最多的5个不同的类别
