# %%
import sys
sys.path.insert(0, '/root/mounted/projects/qpair/')

# %%
import os
DATA_SET_PATH = "/root/mounted/datasets/data_0520/"
KN_PAIRS_CSV = os.path.join(DATA_SET_PATH, 'knowledge_pairs.csv')
TRAIN_PAIRS_CSV = os.path.join(DATA_SET_PATH, 'train_pairs.csv')

# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
kn_pairs = pd.read_csv(KN_PAIRS_CSV, sep='\t')
kn_pairs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 211426140 entries, 0 to 211426139
# Data columns (total 3 columns):
# label    int64
# q1       object
# q2       object
# dtypes: int64(1), object(2)
# memory usage: 4.7+ GB

# %%
kn_pairs.head()
# Out:
#    label       q1       q2
# 0      1  Q514608  Q619944
# 1      1  Q514608  Q097456
# 2      1  Q514608  Q028268
# 3      1  Q514608  Q161476
# 4      1  Q514608  Q665491

# %%
import gc
gc.collect()
# Out:
# 28

# %%
def sample(df, num):
    import numpy as np
#     if random_state:
#         np.random.seed(random_state)
        
    shuffled_indice = np.random.permutation(df.shape[0])
    return df.iloc[shuffled_indice[:num],:].copy(), df.iloc[shuffled_indice[num:],:].copy()


def sample_data_set(all_pairs, target_rate, sampling_number):
    """
    """
    
#     import numpy as np
    
    pos_num = int(sampling_number * target_rate)
    neg_num = sampling_number - pos_num
    
    pos_pairs = all_pairs[all_pairs['label'] == 1]
    neg_pairs = all_pairs[all_pairs['label'] == 0]
    
#     if random_state:
#         np.random.seed(random_state)
    
#     pos_shuffled_indice = np.random.permutation(pos_pairs.shape[0])
#     neg_shuffled_indice = np.random.permutation(neg_pairs.shape[0])
    
#     pos_sampled = pos_pairs.iloc[pos_shuffled_indice[:pos_num], :].copy()
#     neg_sampled = neg_pairs.iloc[neg_shuffled_indice[:neg_num], :].copy()
    pos_sampled = sample(pos_pairs, pos_num)[0]
    neg_sampled = sample(neg_pairs, neg_num)[0]
    return pd.concat([pos_sampled, neg_sampled], ignore_index=True)


def q1_q2_intersect(data):
    from collections import defaultdict
    import pandas as pd
    q_dict = defaultdict(set)
    for i in range(data.shape[0]):
        q_dict[data['q1'][i]].add(data['q2'][i])
        q_dict[data['q2'][i]].add(data['q1'][i])
    
    def intersect(row):
        return(len(set(q_dict[row['q1']]).intersection(set(q_dict[row['q2']]))))
 
    
    return data.apply(intersect, axis = 1)



def split_test_train_set(data_set, target_rate, split_rate = 0.2):
    """
    """
    inter_nums = set(data_set['q1_q2_intersect'])
    sampled_test = []
    sampled_train = []
    for i in inter_nums:
        data = data_set[data_set['q1_q2_intersect'] == i]
        pos_pairs = data[data['label'] == 1]
        neg_pairs = data[data['label'] == 0]
        # pos_split_num = int(pos_pairs.shape[0] * split_rate)
        # neg_split_num = int(neg_pairs.shape[0] * split_rate)
        pos_split_num = int(data.shape[0] * split_rate * target_rate)
        neg_split_num = int(data.shape[0] * split_rate * (1 - target_rate))
        
        if pos_split_num <= pos_pairs.shape[0] and neg_split_num <= neg_pairs.shape[0]:
            pos_pairs_sampled_test, pos_pairs_sampled_train = sample(pos_pairs, pos_split_num)
            neg_pairs_sampled_test, neg_pairs_sampled_train = sample(neg_pairs, neg_split_num)
        
        if pos_split_num > pos_pairs.shape[0]:
            pos_sample_num = int(pos_pairs.shape[0] * split_rate)
#             pos_sample_num = int(pos_pairs.shape[0] * 0.5)
            neg_sample_num = int(pos_sample_num * (1 / target_rate - 1))
            pos_pairs_sampled_test, pos_pairs_sampled_train = sample(pos_pairs, pos_sample_num)
            neg_pairs_sampled_test, neg_pairs_sampled_train = sample(neg_pairs, neg_sample_num)
        
        if neg_split_num > neg_pairs.shape[0]:
            neg_sample_num = int(neg_pairs.shape[0] * split_rate)
#             neg_sample_num = int(neg_pairs.shape[0] *0.5)
            pos_sample_num = int(neg_sample_num * (target_rate / (1 - target_rate)))
            pos_pairs_sampled_test, pos_pairs_sampled_train = sample(pos_pairs, pos_sample_num)
            neg_pairs_sampled_test, neg_pairs_sampled_train = sample(neg_pairs, neg_sample_num)            
        
        sampled_test.append(pd.concat([pos_pairs_sampled_test, neg_pairs_sampled_test],ignore_index=True))
        sampled_train.append(pd.concat([pos_pairs_sampled_train, neg_pairs_sampled_train], ignore_index=True))
    return pd.concat(sampled_test, ignore_index=True), pd.concat(sampled_train, ignore_index=True)

# %%
kn_pairs_sampled = sample_data_set(kn_pairs, 0.3, 800000)
kn_pairs_sampled
# Out:
#         label       q1       q2
# 0           1  Q099012  Q504596
# 1           1  Q203595  Q356683
# 2           1  Q503069  Q418112
# 3           1  Q149724  Q073259
# 4           1  Q437941  Q005482
# 5           1  Q307612  Q364967
# 6           1  Q326873  Q695067
# 7           1  Q248693  Q041585
# 8           1  Q442620  Q550218
# 9           1  Q518504  Q476096
# 10          1  Q547897  Q599121
# 11          1  Q051955  Q634322
# 12          1  Q279040  Q399275
# 13          1  Q222988  Q619300
# 14          1  Q393053  Q599121
# 15          1  Q728324  Q500192
# 16          1  Q656053  Q007692
# 17          1  Q582903  Q168755
# 18          1  Q192309  Q282542
# 19          1  Q115669  Q405217
# 20          1  Q079093  Q398998
# 21          1  Q463429  Q228720
# 22          1  Q276894  Q617347
# 23          1  Q165166  Q689509
# 24          1  Q017374  Q283737
# 25          1  Q635647  Q659879
# 26          1  Q565051  Q584869
# 27          1  Q016807  Q118175
# 28          1  Q261819  Q014388
# 29          1  Q540823  Q299397
# ...       ...      ...      ...
# 799970      0  Q204345  Q549605
# 799971      0  Q585289  Q662583
# 799972      0  Q318491  Q656190
# 799973      0  Q194575  Q521255
# 799974      0  Q487686  Q483306
# 799975      0  Q617886  Q361575
# 799976      0  Q517072  Q488400
# 799977      0  Q449448  Q340116
# 799978      0  Q720025  Q164492
# 799979      0  Q164019  Q257345
# 799980      0  Q362904  Q067249
# 799981      0  Q116409  Q153299
# 799982      0  Q084210  Q026686
# 799983      0  Q269571  Q676737
# 799984      0  Q219384  Q017760
# 799985      0  Q348164  Q216076
# 799986      0  Q342932  Q228157
# 799987      0  Q399275  Q308638
# 799988      0  Q066541  Q436579
# 799989      0  Q148078  Q164341
# 799990      0  Q259448  Q367023
# 799991      0  Q253033  Q626694
# 799992      0  Q268755  Q030466
# 799993      0  Q390701  Q670720
# 799994      0  Q057935  Q340161
# 799995      0  Q283840  Q682926
# 799996      0  Q488917  Q203503
# 799997      0  Q302470  Q062779
# 799998      0  Q089105  Q347067
# 799999      0  Q431201  Q149927
#
# [800000 rows x 3 columns]

# %%
(kn_pairs_sampled.label == 1).sum() / kn_pairs_sampled.shape[0]
# Out:
# 0.3

# %%
kn_pairs_sampled['q1_q2_intersect'] = q1_q2_intersect(kn_pairs_sampled)
kn_pairs_sampled
# Out:
#         label       q1       q2  q1_q2_intersect
# 0           1  Q099012  Q504596              126
# 1           1  Q203595  Q356683               35
# 2           1  Q503069  Q418112               19
# 3           1  Q149724  Q073259                6
# 4           1  Q437941  Q005482               42
# 5           1  Q307612  Q364967              123
# 6           1  Q326873  Q695067               59
# 7           1  Q248693  Q041585               52
# 8           1  Q442620  Q550218               26
# 9           1  Q518504  Q476096                2
# 10          1  Q547897  Q599121              126
# 11          1  Q051955  Q634322               58
# 12          1  Q279040  Q399275               20
# 13          1  Q222988  Q619300                5
# 14          1  Q393053  Q599121              139
# 15          1  Q728324  Q500192               16
# 16          1  Q656053  Q007692              112
# 17          1  Q582903  Q168755              127
# 18          1  Q192309  Q282542               25
# 19          1  Q115669  Q405217               12
# 20          1  Q079093  Q398998               51
# 21          1  Q463429  Q228720               16
# 22          1  Q276894  Q617347               11
# 23          1  Q165166  Q689509                8
# 24          1  Q017374  Q283737               20
# 25          1  Q635647  Q659879              138
# 26          1  Q565051  Q584869               32
# 27          1  Q016807  Q118175                8
# 28          1  Q261819  Q014388               64
# 29          1  Q540823  Q299397               73
# ...       ...      ...      ...              ...
# 799970      0  Q204345  Q549605                0
# 799971      0  Q585289  Q662583                1
# 799972      0  Q318491  Q656190                1
# 799973      0  Q194575  Q521255                1
# 799974      0  Q487686  Q483306                3
# 799975      0  Q617886  Q361575                0
# 799976      0  Q517072  Q488400                0
# 799977      0  Q449448  Q340116                0
# 799978      0  Q720025  Q164492                0
# 799979      0  Q164019  Q257345                2
# 799980      0  Q362904  Q067249                1
# 799981      0  Q116409  Q153299                0
# 799982      0  Q084210  Q026686                1
# 799983      0  Q269571  Q676737                1
# 799984      0  Q219384  Q017760                1
# 799985      0  Q348164  Q216076                2
# 799986      0  Q342932  Q228157                1
# 799987      0  Q399275  Q308638                0
# 799988      0  Q066541  Q436579                0
# 799989      0  Q148078  Q164341                0
# 799990      0  Q259448  Q367023                0
# 799991      0  Q253033  Q626694                1
# 799992      0  Q268755  Q030466                0
# 799993      0  Q390701  Q670720                0
# 799994      0  Q057935  Q340161                0
# 799995      0  Q283840  Q682926                1
# 799996      0  Q488917  Q203503                0
# 799997      0  Q302470  Q062779                2
# 799998      0  Q089105  Q347067                0
# 799999      0  Q431201  Q149927                0
#
# [800000 rows x 4 columns]

# %%
kn_pairs_sampled_inter = kn_pairs_sampled.q1_q2_intersect.value_counts()
kn_pairs_sampled_inter.sort_index(inplace=True)
kn_pairs_sampled_inter
# Out:
# 0      289551
# 1      185618
# 2       67236
# 3       21607
# 4        9783
# 5        6833
# 6        5832
# 7        5444
# 8        4796
# 9        4284
# 10       3942
# 11       3548
# 12       3367
# 13       3230
# 14       3376
# 15       3288
# 16       3316
# 17       3279
# 18       3368
# 19       3349
# 20       3311
# 21       3241
# 22       3262
# 23       2944
# 24       2914
# 25       2811
# 26       2835
# 27       2856
# 28       2900
# 29       3007
#         ...
# 133      1429
# 134      1405
# 135      1278
# 136      1111
# 137       963
# 138       903
# 139       777
# 140       549
# 141       550
# 142       426
# 143       312
# 144       285
# 145       264
# 146       227
# 147       139
# 148       116
# 149        91
# 150        77
# 151        46
# 152        24
# 153        32
# 154        25
# 155        12
# 156        21
# 157         6
# 158         2
# 159         1
# 161         1
# 164         1
# 165         1
# Name: q1_q2_intersect, Length: 163, dtype: int64

# %%
plt.bar(kn_pairs_sampled_inter.index, kn_pairs_sampled_inter.values)
# Out:
# <BarContainer object of 163 artists>

# %%
kn_pairs_sampled_test, kn_pairs_sampled_train = split_test_train_set(kn_pairs_sampled, 0.3)

# %%
kn_pairs_sampled_test
# Out:
#        label       q1       q2  q1_q2_intersect
# 0          1  Q292134  Q714141                0
# 1          1  Q390603  Q137731                0
# 2          1  Q634500  Q726317                0
# 3          1  Q682779  Q070021                0
# 4          1  Q281944  Q314446                0
# 5          1  Q067697  Q450723                0
# 6          1  Q692024  Q494363                0
# 7          1  Q614656  Q356821                0
# 8          1  Q318923  Q474654                0
# 9          1  Q210938  Q714857                0
# 10         1  Q493322  Q586781                0
# 11         1  Q381846  Q124556                0
# 12         1  Q081488  Q407411                0
# 13         1  Q444926  Q178271                0
# 14         1  Q698205  Q183361                0
# 15         1  Q364420  Q660386                0
# 16         1  Q707260  Q626339                0
# 17         1  Q031632  Q420041                0
# 18         1  Q069563  Q286713                0
# 19         1  Q437859  Q276788                0
# 20         1  Q061068  Q310205                0
# 21         1  Q438222  Q460963                0
# 22         1  Q158256  Q105346                0
# 23         1  Q471469  Q608919                0
# 24         1  Q660272  Q298983                0
# 25         1  Q364084  Q246620                0
# 26         1  Q649541  Q352818                0
# 27         1  Q021594  Q266136                0
# 28         1  Q536714  Q031632                0
# 29         1  Q152244  Q196282                0
# ...      ...      ...      ...              ...
# 15157      0  Q165570  Q096805                7
# 15158      0  Q273689  Q309664                7
# 15159      0  Q058531  Q543100                7
# 15160      0  Q156251  Q519059                7
# 15161      0  Q333069  Q623507                7
# 15162      0  Q468180  Q534431                7
# 15163      0  Q239678  Q442076                7
# 15164      0  Q063748  Q505513                7
# 15165      0  Q447501  Q711790                7
# 15166      0  Q543100  Q058531                7
# 15167      0  Q238058  Q155588                7
# 15168      0  Q410852  Q531374                7
# 15169      0  Q162721  Q058531                7
# 15170      0  Q362897  Q567402                7
# 15171      0  Q530856  Q534201                7
# 15172      0  Q388323  Q113750                7
# 15173      0  Q119763  Q061290                7
# 15174      0  Q352131  Q661937                7
# 15175      0  Q338299  Q354378                7
# 15176      0  Q000777  Q321890                7
# 15177      0  Q673338  Q700334                7
# 15178      0  Q174314  Q116226                7
# 15179      1  Q156140  Q582474                8
# 15180      1  Q545471  Q020178                8
# 15181      0  Q202245  Q442076                8
# 15182      0  Q595045  Q531374                8
# 15183      0  Q308880  Q058531                8
# 15184      0  Q403462  Q006182                8
# 15185      0  Q482630  Q595045                8
# 15186      0  Q341068  Q645323                9
#
# [15187 rows x 4 columns]

# %%
kn_pairs_sampled_train
# Out:
#         label       q1       q2  q1_q2_intersect
# 0           1  Q369872  Q425580                0
# 1           1  Q647775  Q544605                0
# 2           1  Q590852  Q444014                0
# 3           1  Q463651  Q029012                0
# 4           1  Q254992  Q024935                0
# 5           1  Q213901  Q675941                0
# 6           1  Q442871  Q037871                0
# 7           1  Q178756  Q294508                0
# 8           1  Q153830  Q295899                0
# 9           1  Q378749  Q285502                0
# 10          1  Q615719  Q014435                0
# 11          1  Q345476  Q067435                0
# 12          1  Q344702  Q181543                0
# 13          1  Q096127  Q488793                0
# 14          1  Q135443  Q699495                0
# 15          1  Q603619  Q687515                0
# 16          1  Q542200  Q650464                0
# 17          1  Q622505  Q649377                0
# 18          1  Q236269  Q280890                0
# 19          1  Q218043  Q540218                0
# 20          1  Q130914  Q691116                0
# 21          1  Q402874  Q461718                0
# 22          1  Q397680  Q199984                0
# 23          1  Q094550  Q628451                0
# 24          1  Q593469  Q405690                0
# 25          1  Q030371  Q218953                0
# 26          1  Q322382  Q201057                0
# 27          1  Q725838  Q492029                0
# 28          1  Q687515  Q603619                0
# 29          1  Q288346  Q548807                0
# ...       ...      ...      ...              ...
# 784783      1  Q196182  Q482630              156
# 784784      1  Q482630  Q196182              156
# 784785      1  Q587309  Q174315              156
# 784786      1  Q537024  Q482630              156
# 784787      1  Q174315  Q587309              156
# 784788      1  Q482630  Q021885              156
# 784789      1  Q543100  Q196182              156
# 784790      1  Q441656  Q482630              156
# 784791      1  Q500244  Q645635              156
# 784792      1  Q270713  Q645635              156
# 784793      1  Q724628  Q482630              156
# 784794      1  Q246427  Q174315              156
# 784795      1  Q362897  Q443340              156
# 784796      1  Q060369  Q500244              156
# 784797      1  Q359907  Q558278              156
# 784798      1  Q645635  Q500244              156
# 784799      1  Q196182  Q543100              156
# 784800      1  Q021885  Q482630              156
# 784801      1  Q537024  Q174315              157
# 784802      1  Q558278  Q500244              157
# 784803      1  Q060159  Q537024              157
# 784804      1  Q270713  Q359907              157
# 784805      1  Q555108  Q482630              157
# 784806      1  Q174315  Q537024              157
# 784807      1  Q482630  Q270713              158
# 784808      1  Q011634  Q482630              158
# 784809      1  Q500244  Q482630              159
# 784810      1  Q174315  Q202128              161
# 784811      1  Q482630  Q315621              164
# 784812      1  Q174315  Q482630              165
#
# [784813 rows x 4 columns]

# %%
def plot_pos_vs_neg(df, intersect):
    data = df[df.q1_q2_intersect == intersect]
    pos_num = len(data[data['label'] == 1])
    neg_num = len(data[data['label'] == 0])
    plt.bar(['pos', 'neg'], [pos_num, neg_num])
    return pos_num, neg_num

# %%
plot_pos_vs_neg(kn_pairs_sampled_test, 0)
# Out:
# (212, 494)

# %%
plot_pos_vs_neg(kn_pairs_sampled_test, 1)
# Out:
# (704, 1642)

# %%
plot_pos_vs_neg(kn_pairs_sampled_test, 2)
# Out:
# (1502, 3504)

# %%
plot_pos_vs_neg(kn_pairs_sampled_test, 3)
# Out:
# (1296, 3024)

# %%
plot_pos_vs_neg(kn_pairs_sampled_test, 4)
# Out:
# (586, 1369)

# %%
plot_pos_vs_neg(kn_pairs_sampled_test, 4)
# Out:
# (586, 1369)

# %%
temp = kn_pairs_sampled[kn_pairs_sampled['q1_q2_intersect']==2]

# %%
temp.shape
# Out:
# (67236, 4)

# %%
temp[temp.label == 1].shape, temp[temp.label == 0].shape
# Out:
# ((3005, 4), (64231, 4))

# %%
plot_pos_vs_neg(kn_pairs_sampled_test, 3)
# Out:
# (1296, 3024)

# %%
plot_pos_vs_neg(kn_pairs_sampled_train, 0)
# Out:
# (212, 288633)

# %%
plot_pos_vs_neg(kn_pairs_sampled_train, 1)
# Out:
# (705, 182567)

# %%
plot_pos_vs_neg(kn_pairs_sampled_train, 2)
# Out:
# (1503, 60727)

# %%
plot_pos_vs_neg(kn_pairs_sampled_train, 3)
# Out:
# (3208, 14079)

# %%
plot_pos_vs_neg(kn_pairs_sampled_train, 4)
# Out:
# (5066, 2762)

# %%
plot_pos_vs_neg(kn_pairs_sampled_train, 10)
# Out:
# (3942, 0)

# %%
(kn_pairs_sampled_train['label'] == 1).sum(), (kn_pairs_sampled_train['label'] == 1).sum() / ((kn_pairs_sampled_train['label'] == 1).sum() + (kn_pairs_sampled_train['label'] == 0).sum())
# Out:
# (235445, 0.30000140160777156)

# %%
kn_pairs_sampled_train
# Out:
#         label       q1       q2  q1_q2_intersect
# 0           1  Q369872  Q425580                0
# 1           1  Q647775  Q544605                0
# 2           1  Q590852  Q444014                0
# 3           1  Q463651  Q029012                0
# 4           1  Q254992  Q024935                0
# 5           1  Q213901  Q675941                0
# 6           1  Q442871  Q037871                0
# 7           1  Q178756  Q294508                0
# 8           1  Q153830  Q295899                0
# 9           1  Q378749  Q285502                0
# 10          1  Q615719  Q014435                0
# 11          1  Q345476  Q067435                0
# 12          1  Q344702  Q181543                0
# 13          1  Q096127  Q488793                0
# 14          1  Q135443  Q699495                0
# 15          1  Q603619  Q687515                0
# 16          1  Q542200  Q650464                0
# 17          1  Q622505  Q649377                0
# 18          1  Q236269  Q280890                0
# 19          1  Q218043  Q540218                0
# 20          1  Q130914  Q691116                0
# 21          1  Q402874  Q461718                0
# 22          1  Q397680  Q199984                0
# 23          1  Q094550  Q628451                0
# 24          1  Q593469  Q405690                0
# 25          1  Q030371  Q218953                0
# 26          1  Q322382  Q201057                0
# 27          1  Q725838  Q492029                0
# 28          1  Q687515  Q603619                0
# 29          1  Q288346  Q548807                0
# ...       ...      ...      ...              ...
# 784783      1  Q196182  Q482630              156
# 784784      1  Q482630  Q196182              156
# 784785      1  Q587309  Q174315              156
# 784786      1  Q537024  Q482630              156
# 784787      1  Q174315  Q587309              156
# 784788      1  Q482630  Q021885              156
# 784789      1  Q543100  Q196182              156
# 784790      1  Q441656  Q482630              156
# 784791      1  Q500244  Q645635              156
# 784792      1  Q270713  Q645635              156
# 784793      1  Q724628  Q482630              156
# 784794      1  Q246427  Q174315              156
# 784795      1  Q362897  Q443340              156
# 784796      1  Q060369  Q500244              156
# 784797      1  Q359907  Q558278              156
# 784798      1  Q645635  Q500244              156
# 784799      1  Q196182  Q543100              156
# 784800      1  Q021885  Q482630              156
# 784801      1  Q537024  Q174315              157
# 784802      1  Q558278  Q500244              157
# 784803      1  Q060159  Q537024              157
# 784804      1  Q270713  Q359907              157
# 784805      1  Q555108  Q482630              157
# 784806      1  Q174315  Q537024              157
# 784807      1  Q482630  Q270713              158
# 784808      1  Q011634  Q482630              158
# 784809      1  Q500244  Q482630              159
# 784810      1  Q174315  Q202128              161
# 784811      1  Q482630  Q315621              164
# 784812      1  Q174315  Q482630              165
#
# [784813 rows x 4 columns]

# %%
KN_PAIRS_SAMPLED_TRAIN_CSV = os.path.join(DATA_SET_PATH, 'intermediate/kn_pairs_sampled_train.csv')
KN_PAIRS_SAMPLED_TEST_CSV = os.path.join(DATA_SET_PATH, 'intermediate/kn_pairs_sampled_test.csv')
kn_pairs_sampled_train.to_csv(KN_PAIRS_SAMPLED_TRAIN_CSV, index=False)
kn_pairs_sampled_test.to_csv(KN_PAIRS_SAMPLED_TEST_CSV, index=False)
