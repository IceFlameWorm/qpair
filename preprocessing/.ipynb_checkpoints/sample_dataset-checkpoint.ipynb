# %%
import sys
sys.path.insert(0, '/root/mounted/projects/qpair/')

# %%
import os
DATA_SET_PATH = "/root/mounted/datasets/data_0521/"
KN_PAIRS_CSV = os.path.join(DATA_SET_PATH, 'knowledge_pairs.csv')
TRAIN_PAIRS_CSV = os.path.join(DATA_SET_PATH, 'train_pairs.csv')

# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
kn_pairs = pd.read_csv(KN_PAIRS_CSV, sep='\t')
kn_pairs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105713070 entries, 0 to 105713069
# Data columns (total 3 columns):
# label    int64
# q1       object
# q2       object
# dtypes: int64(1), object(2)
# memory usage: 2.4+ GB

# %%
kn_pairs.head()
# Out:
#    label       q1       q2
# 0      1  Q514608  Q619944
# 1      1  Q514608  Q097456
# 2      1  Q514608  Q028268
# 3      1  Q514608  Q161476
# 4      1  Q514608  Q665491

# %%
train_pairs_with_cid = pd.read_csv(TRAIN_PAIRS_CSV, sep='\t')
train_pairs = train_pairs_with_cid.drop('cid',axis=1)
train_pairs
# Out:
#          label       q1       q2
# 0            1  Q330567  Q377415
# 1            1  Q330567  Q567601
# 2            1  Q330567  Q436081
# 3            1  Q330567  Q036391
# 4            1  Q330567  Q209042
# 5            1  Q330567  Q353992
# 6            1  Q330567  Q648488
# 7            1  Q330567  Q086532
# 8            1  Q330567  Q544178
# 9            1  Q330567  Q085589
# 10           1  Q330567  Q296575
# 11           1  Q330567  Q222096
# 12           1  Q330567  Q219993
# 13           1  Q330567  Q571386
# 14           1  Q330567  Q522453
# 15           1  Q330567  Q671234
# 16           1  Q330567  Q287045
# 17           1  Q330567  Q594457
# 18           1  Q330567  Q211751
# 19           1  Q330567  Q466495
# 20           1  Q330567  Q015850
# 21           1  Q330567  Q195819
# 22           1  Q330567  Q139360
# 23           1  Q330567  Q014237
# 24           1  Q330567  Q160968
# 25           1  Q330567  Q363572
# 26           1  Q330567  Q027411
# 27           1  Q330567  Q080239
# 28           1  Q330567  Q569797
# 29           1  Q330567  Q655498
# ...        ...      ...      ...
# 4049410      0  Q454537  Q654714
# 4049411      0  Q454537  Q475388
# 4049412      0  Q454537  Q151261
# 4049413      0  Q454537  Q583905
# 4049414      0  Q454537  Q445955
# 4049415      0  Q454537  Q391587
# 4049416      0  Q454537  Q389077
# 4049417      0  Q454537  Q213526
# 4049418      0  Q454537  Q117968
# 4049419      0  Q454537  Q654433
# 4049420      0  Q454537  Q259776
# 4049421      0  Q454537  Q683763
# 4049422      0  Q454537  Q705252
# 4049423      0  Q454537  Q673338
# 4049424      0  Q454537  Q262218
# 4049425      0  Q454537  Q064157
# 4049426      0  Q454537  Q447592
# 4049427      0  Q454537  Q014793
# 4049428      0  Q454537  Q618999
# 4049429      0  Q454537  Q051805
# 4049430      0  Q454537  Q428012
# 4049431      0  Q454537  Q683320
# 4049432      0  Q454537  Q454918
# 4049433      0  Q454537  Q503911
# 4049434      0  Q454537  Q288883
# 4049435      0  Q454537  Q125163
# 4049436      0  Q454537  Q615514
# 4049437      0  Q454537  Q432969
# 4049438      0  Q454537  Q002362
# 4049439      0  Q454537  Q310680
#
# [4049440 rows x 3 columns]

# %%
kn_train_pairs = pd.concat([kn_pairs, train_pairs])
kn_pairs = kn_train_pairs.reset_index(drop=True)
kn_pairs
# Out:
#            label       q1       q2
# 0              1  Q514608  Q619944
# 1              1  Q514608  Q097456
# 2              1  Q514608  Q028268
# 3              1  Q514608  Q161476
# 4              1  Q514608  Q665491
# 5              0  Q514608  Q131177
# 6              0  Q514608  Q336221
# 7              0  Q514608  Q659732
# 8              0  Q514608  Q686996
# 9              0  Q514608  Q630751
# 10             0  Q514608  Q310210
# 11             0  Q514608  Q617970
# 12             0  Q514608  Q523929
# 13             0  Q514608  Q498651
# 14             0  Q514608  Q121850
# 15             0  Q514608  Q695233
# 16             0  Q514608  Q401475
# 17             0  Q514608  Q374962
# 18             0  Q514608  Q599198
# 19             0  Q514608  Q529978
# 20             0  Q514608  Q448592
# 21             0  Q514608  Q452426
# 22             0  Q514608  Q203655
# 23             0  Q514608  Q112907
# 24             0  Q514608  Q601185
# 25             0  Q514608  Q555026
# 26             0  Q514608  Q080865
# 27             0  Q514608  Q210719
# 28             0  Q514608  Q686458
# 29             0  Q514608  Q475219
# ...          ...      ...      ...
# 109762480      0  Q454537  Q654714
# 109762481      0  Q454537  Q475388
# 109762482      0  Q454537  Q151261
# 109762483      0  Q454537  Q583905
# 109762484      0  Q454537  Q445955
# 109762485      0  Q454537  Q391587
# 109762486      0  Q454537  Q389077
# 109762487      0  Q454537  Q213526
# 109762488      0  Q454537  Q117968
# 109762489      0  Q454537  Q654433
# 109762490      0  Q454537  Q259776
# 109762491      0  Q454537  Q683763
# 109762492      0  Q454537  Q705252
# 109762493      0  Q454537  Q673338
# 109762494      0  Q454537  Q262218
# 109762495      0  Q454537  Q064157
# 109762496      0  Q454537  Q447592
# 109762497      0  Q454537  Q014793
# 109762498      0  Q454537  Q618999
# 109762499      0  Q454537  Q051805
# 109762500      0  Q454537  Q428012
# 109762501      0  Q454537  Q683320
# 109762502      0  Q454537  Q454918
# 109762503      0  Q454537  Q503911
# 109762504      0  Q454537  Q288883
# 109762505      0  Q454537  Q125163
# 109762506      0  Q454537  Q615514
# 109762507      0  Q454537  Q432969
# 109762508      0  Q454537  Q002362
# 109762509      0  Q454537  Q310680
#
# [109762510 rows x 3 columns]

# %%
import gc
gc.collect()
# Out:
# 110

# %%
def sample(df, num):
    import numpy as np
#     if random_state:
#         np.random.seed(random_state)
        
    shuffled_indice = np.random.permutation(df.shape[0])
    return df.iloc[shuffled_indice[:num],:].copy(), df.iloc[shuffled_indice[num:],:].copy()


def sample_data_set(all_pairs, target_rate, sampling_number):
    """
    """
    
#     import numpy as np
    
    pos_num = int(sampling_number * target_rate)
    neg_num = sampling_number - pos_num
    
    pos_pairs = all_pairs[all_pairs['label'] == 1]
    neg_pairs = all_pairs[all_pairs['label'] == 0]
    
#     if random_state:
#         np.random.seed(random_state)
    
#     pos_shuffled_indice = np.random.permutation(pos_pairs.shape[0])
#     neg_shuffled_indice = np.random.permutation(neg_pairs.shape[0])
    
#     pos_sampled = pos_pairs.iloc[pos_shuffled_indice[:pos_num], :].copy()
#     neg_sampled = neg_pairs.iloc[neg_shuffled_indice[:neg_num], :].copy()
    pos_sampled = sample(pos_pairs, pos_num)[0]
    neg_sampled = sample(neg_pairs, neg_num)[0]
    return pd.concat([pos_sampled, neg_sampled], ignore_index=True)


def q1_q2_intersect(data):
    from collections import defaultdict
    import pandas as pd
    q_dict = defaultdict(set)
    for i in range(data.shape[0]):
        q_dict[data['q1'][i]].add(data['q2'][i])
        q_dict[data['q2'][i]].add(data['q1'][i])
    
    def intersect(row):
        return(len(set(q_dict[row['q1']]).intersection(set(q_dict[row['q2']]))))
 
    
    return data.apply(intersect, axis = 1)


def split_test_train_set(data_set, target_rate, split_rate = 0.2):
    """
    """
    inter_nums = set(data_set['q1_q2_intersect'])
    sampled_test = []
    sampled_train = []
    for i in inter_nums:
        data = data_set[data_set['q1_q2_intersect'] == i]
        pos_pairs = data[data['label'] == 1]
        neg_pairs = data[data['label'] == 0]
        # pos_split_num = int(pos_pairs.shape[0] * split_rate)
        # neg_split_num = int(neg_pairs.shape[0] * split_rate)
        pos_split_num = int(data.shape[0] * split_rate * target_rate)
        neg_split_num = int(data.shape[0] * split_rate * (1 - target_rate))
        
        if pos_split_num <= pos_pairs.shape[0] and neg_split_num <= neg_pairs.shape[0]:
            pos_pairs_sampled_test, pos_pairs_sampled_train = sample(pos_pairs, pos_split_num)
            neg_pairs_sampled_test, neg_pairs_sampled_train = sample(neg_pairs, neg_split_num)
        
        if pos_split_num > pos_pairs.shape[0]:
#             pos_sample_num = int(pos_pairs.shape[0] * split_rate)
            pos_sample_num = int(pos_pairs.shape[0] * 0.5)
            neg_sample_num = int(pos_sample_num * (1 / target_rate - 1))
            pos_pairs_sampled_test, pos_pairs_sampled_train = sample(pos_pairs, pos_sample_num)
            neg_pairs_sampled_test, neg_pairs_sampled_train = sample(neg_pairs, neg_sample_num)
        
        if neg_split_num > neg_pairs.shape[0]:
#             neg_sample_num = int(neg_pairs.shape[0] * split_rate)
            neg_sample_num = int(neg_pairs.shape[0] *0.5)
            pos_sample_num = int(neg_sample_num * (target_rate / (1 - target_rate)))
            pos_pairs_sampled_test, pos_pairs_sampled_train = sample(pos_pairs, pos_sample_num)
            neg_pairs_sampled_test, neg_pairs_sampled_train = sample(neg_pairs, neg_sample_num)            
        
        sampled_test.append(pd.concat([pos_pairs_sampled_test, neg_pairs_sampled_test],ignore_index=True))
        sampled_train.append(pd.concat([pos_pairs_sampled_train, neg_pairs_sampled_train], ignore_index=True))
    return pd.concat(sampled_test, ignore_index=True), pd.concat(sampled_train, ignore_index=True)

# %%
kn_pairs_sampled = sample_data_set(kn_pairs, 0.3, 400000)
kn_pairs_sampled
# Out:
#         label       q1       q2
# 0           1  Q162320  Q573688
# 1           1  Q091408  Q041344
# 2           1  Q580723  Q039394
# 3           1  Q563039  Q141944
# 4           1  Q138764  Q054898
# 5           1  Q182104  Q552474
# 6           1  Q354530  Q307406
# 7           1  Q233288  Q519882
# 8           1  Q188124  Q268131
# 9           1  Q173460  Q689561
# 10          1  Q454537  Q644268
# 11          1  Q226478  Q592622
# 12          1  Q585513  Q438008
# 13          1  Q487436  Q523120
# 14          1  Q339892  Q495371
# 15          1  Q323040  Q270690
# 16          1  Q686617  Q571099
# 17          1  Q264488  Q376281
# 18          1  Q190561  Q621438
# 19          1  Q364967  Q489149
# 20          1  Q475330  Q408167
# 21          1  Q065753  Q648430
# 22          1  Q120493  Q057845
# 23          1  Q548028  Q473230
# 24          1  Q688897  Q473230
# 25          1  Q124230  Q386560
# 26          1  Q467582  Q276936
# 27          1  Q124262  Q060681
# 28          1  Q688532  Q127976
# 29          1  Q367923  Q299546
# ...       ...      ...      ...
# 199970      0  Q527285  Q728410
# 199971      0  Q507699  Q351740
# 199972      0  Q592134  Q464450
# 199973      0  Q013170  Q123075
# 199974      0  Q178113  Q034366
# 199975      0  Q178525  Q722597
# 199976      0  Q654175  Q546974
# 199977      0  Q482539  Q284034
# 199978      0  Q120955  Q597703
# 199979      0  Q385104  Q704944
# 199980      0  Q149724  Q279768
# 199981      0  Q359784  Q204685
# 199982      0  Q500190  Q051805
# 199983      0  Q364352  Q612422
# 199984      0  Q103365  Q451945
# 199985      0  Q179303  Q386041
# 199986      0  Q129731  Q564937
# 199987      0  Q708502  Q604064
# 199988      0  Q049061  Q656641
# 199989      0  Q154905  Q478272
# 199990      0  Q541286  Q152869
# 199991      0  Q232236  Q633990
# 199992      0  Q389051  Q467256
# 199993      0  Q353535  Q277727
# 199994      0  Q312464  Q234595
# 199995      0  Q678513  Q434810
# 199996      0  Q594025  Q477695
# 199997      0  Q059861  Q358680
# 199998      0  Q368124  Q011786
# 199999      0  Q487457  Q176380
#
# [200000 rows x 3 columns]

# %%
(kn_pairs_sampled.label == 1).sum() / kn_pairs_sampled.shape[0]
# Out:
# 0.3

# %%
kn_pairs_sampled['q1_q2_intersect'] = q1_q2_intersect(kn_pairs_sampled)
kn_pairs_sampled
# Out:
#         label       q1       q2  q1_q2_intersect
# 0           1  Q162320  Q573688                0
# 1           1  Q091408  Q041344                0
# 2           1  Q580723  Q039394                0
# 3           1  Q563039  Q141944                0
# 4           1  Q138764  Q054898                0
# 5           1  Q182104  Q552474                1
# 6           1  Q354530  Q307406                0
# 7           1  Q233288  Q519882                0
# 8           1  Q188124  Q268131                0
# 9           1  Q173460  Q689561                0
# 10          1  Q454537  Q644268                0
# 11          1  Q226478  Q592622                0
# 12          1  Q585513  Q438008                0
# 13          1  Q487436  Q523120                0
# 14          1  Q339892  Q495371                0
# 15          1  Q323040  Q270690                0
# 16          1  Q686617  Q571099                0
# 17          1  Q264488  Q376281                0
# 18          1  Q190561  Q621438                0
# 19          1  Q364967  Q489149                1
# 20          1  Q475330  Q408167                0
# 21          1  Q065753  Q648430                0
# 22          1  Q120493  Q057845                0
# 23          1  Q548028  Q473230                0
# 24          1  Q688897  Q473230                0
# 25          1  Q124230  Q386560                1
# 26          1  Q467582  Q276936                0
# 27          1  Q124262  Q060681                0
# 28          1  Q688532  Q127976                0
# 29          1  Q367923  Q299546                0
# ...       ...      ...      ...              ...
# 199970      0  Q527285  Q728410                0
# 199971      0  Q507699  Q351740                0
# 199972      0  Q592134  Q464450                0
# 199973      0  Q013170  Q123075                0
# 199974      0  Q178113  Q034366                0
# 199975      0  Q178525  Q722597                0
# 199976      0  Q654175  Q546974                0
# 199977      0  Q482539  Q284034                0
# 199978      0  Q120955  Q597703                0
# 199979      0  Q385104  Q704944                0
# 199980      0  Q149724  Q279768                0
# 199981      0  Q359784  Q204685                0
# 199982      0  Q500190  Q051805                0
# 199983      0  Q364352  Q612422                0
# 199984      0  Q103365  Q451945                0
# 199985      0  Q179303  Q386041                0
# 199986      0  Q129731  Q564937                0
# 199987      0  Q708502  Q604064                0
# 199988      0  Q049061  Q656641                0
# 199989      0  Q154905  Q478272                0
# 199990      0  Q541286  Q152869                0
# 199991      0  Q232236  Q633990                0
# 199992      0  Q389051  Q467256                0
# 199993      0  Q353535  Q277727                0
# 199994      0  Q312464  Q234595                1
# 199995      0  Q678513  Q434810                0
# 199996      0  Q594025  Q477695                0
# 199997      0  Q059861  Q358680                0
# 199998      0  Q368124  Q011786                0
# 199999      0  Q487457  Q176380                0
#
# [200000 rows x 4 columns]

# %%
kn_pairs_sampled_inter = kn_pairs_sampled.q1_q2_intersect.value_counts()
kn_pairs_sampled_inter.sort_index(inplace=True)
kn_pairs_sampled_inter
# Out:
# 0    179012
# 1     16217
# 2      3279
# 3       946
# 4       369
# 5       121
# 6        40
# 7        12
# 8         4
# Name: q1_q2_intersect, dtype: int64

# %%
plt.bar(kn_pairs_sampled_inter.index, kn_pairs_sampled_inter.values)
# Out:
# <BarContainer object of 9 artists>

# %%
kn_pairs_sampled_test, kn_pairs_sampled_train = split_test_train_set(kn_pairs_sampled, 0.3)

# %%
# kn_pairs_sampled_test_for_test, kn_pairs_sampled_test_for_train = sample(kn_pairs_sampled_test, int(kn_pairs_sampled_test.shape[0]*0.5))
# kn_pairs_sampled_train = pd.concat([kn_pairs_sampled_train, kn_pairs_sampled_test_for_train])
# kn_pairs_sampled_train = kn_pairs_sampled_train.reset_index(drop=True)
# kn_pairs_sampled_train

# %%
# kn_pairs_sampled_test = kn_pairs_sampled_test_for_test.reset_index(drop=True)

# %%
kn_pairs_sampled_test.shape
# Out:
# (39091, 4)

# %%
kn_pairs_sampled_test
# Out:
#        label       q1       q2  q1_q2_intersect
# 0          1  Q279541  Q299397                0
# 1          1  Q418232  Q570967                0
# 2          1  Q298641  Q613598                0
# 3          1  Q511051  Q577686                0
# 4          1  Q658904  Q344596                0
# 5          1  Q515922  Q149667                0
# 6          1  Q492724  Q060056                0
# 7          1  Q357786  Q672670                0
# 8          1  Q512620  Q119498                0
# 9          1  Q030047  Q427807                0
# 10         1  Q006149  Q424218                0
# 11         1  Q188445  Q537779                0
# 12         1  Q026923  Q700334                0
# 13         1  Q211284  Q233534                0
# 14         1  Q119365  Q313276                0
# 15         1  Q340709  Q267770                0
# 16         1  Q670307  Q458137                0
# 17         1  Q622572  Q398598                0
# 18         1  Q473583  Q688913                0
# 19         1  Q460638  Q059947                0
# 20         1  Q476785  Q161763                0
# 21         1  Q418431  Q540473                0
# 22         1  Q337189  Q306383                0
# 23         1  Q636886  Q145397                0
# 24         1  Q659533  Q030466                0
# 25         1  Q030666  Q165469                0
# 26         1  Q532574  Q513849                0
# 27         1  Q205731  Q181113                0
# 28         1  Q709899  Q175656                0
# 29         1  Q335294  Q648210                0
# ...      ...      ...      ...              ...
# 39061      0  Q553458  Q434748                2
# 39062      0  Q220746  Q271288                2
# 39063      0  Q493420  Q317925                2
# 39064      0  Q067269  Q526407                2
# 39065      0  Q002306  Q668102                2
# 39066      0  Q369671  Q544399                2
# 39067      0  Q546312  Q401391                2
# 39068      0  Q403276  Q474527                2
# 39069      0  Q396035  Q219318                2
# 39070      0  Q351949  Q327338                2
# 39071      0  Q224826  Q206886                2
# 39072      0  Q142534  Q598873                2
# 39073      0  Q541003  Q263471                2
# 39074      0  Q361500  Q511956                2
# 39075      0  Q107746  Q594935                2
# 39076      0  Q725967  Q632555                2
# 39077      0  Q667698  Q644931                2
# 39078      0  Q627713  Q193471                2
# 39079      0  Q251324  Q525009                2
# 39080      0  Q206911  Q016807                2
# 39081      0  Q201808  Q004714                2
# 39082      0  Q335873  Q185110                2
# 39083      0  Q127780  Q125883                2
# 39084      0  Q094611  Q051543                2
# 39085      0  Q216059  Q123163                2
# 39086      0  Q505538  Q179358                2
# 39087      0  Q489183  Q283840                2
# 39088      0  Q452782  Q400772                2
# 39089      0  Q271103  Q099561                2
# 39090      0  Q399394  Q487043                2
#
# [39091 rows x 4 columns]

# %%
kn_pairs_sampled_train
# Out:
#         label       q1       q2  q1_q2_intersect
# 0           1  Q551771  Q519781                0
# 1           1  Q159309  Q275150                0
# 2           1  Q273703  Q455983                0
# 3           1  Q251674  Q693113                0
# 4           1  Q356129  Q636895                0
# 5           1  Q032964  Q427901                0
# 6           1  Q725121  Q061195                0
# 7           1  Q722645  Q681563                0
# 8           1  Q642737  Q590544                0
# 9           1  Q066508  Q573688                0
# 10          1  Q456113  Q480142                0
# 11          1  Q028018  Q444976                0
# 12          1  Q580970  Q021315                0
# 13          1  Q285073  Q428275                0
# 14          1  Q392078  Q033290                0
# 15          1  Q190463  Q315679                0
# 16          1  Q503854  Q529423                0
# 17          1  Q665030  Q375924                0
# 18          1  Q181087  Q283928                0
# 19          1  Q167355  Q624931                0
# 20          1  Q448950  Q565861                0
# 21          1  Q447582  Q199547                0
# 22          1  Q080422  Q074582                0
# 23          1  Q726508  Q100099                0
# 24          1  Q425630  Q505409                0
# 25          1  Q724991  Q374285                0
# 26          1  Q465993  Q180517                0
# 27          1  Q714440  Q399469                0
# 28          1  Q632956  Q100099                0
# 29          1  Q556729  Q056824                0
# ...       ...      ...      ...              ...
# 160879      1  Q724628  Q621258                6
# 160880      1  Q142598  Q348862                6
# 160881      1  Q339303  Q139612                6
# 160882      1  Q595401  Q424359                6
# 160883      1  Q714501  Q397345                6
# 160884      1  Q552953  Q581811                6
# 160885      1  Q661937  Q336995                6
# 160886      1  Q654197  Q452416                6
# 160887      1  Q180060  Q512266                6
# 160888      1  Q685446  Q520567                6
# 160889      1  Q339303  Q066137                6
# 160890      1  Q414588  Q127141                6
# 160891      1  Q473488  Q173464                6
# 160892      1  Q269490  Q185442                6
# 160893      1  Q244746  Q583345                7
# 160894      1  Q390548  Q660889                7
# 160895      1  Q255389  Q578889                7
# 160896      1  Q091001  Q328268                7
# 160897      1  Q697402  Q421188                7
# 160898      1  Q555455  Q225809                7
# 160899      1  Q067269  Q133646                7
# 160900      1  Q715144  Q062356                7
# 160901      1  Q493240  Q562867                7
# 160902      1  Q665518  Q026923                7
# 160903      1  Q066137  Q646250                7
# 160904      1  Q583345  Q097947                7
# 160905      1  Q328268  Q305794                8
# 160906      1  Q644268  Q225809                8
# 160907      1  Q442262  Q076902                8
# 160908      1  Q380993  Q615659                8
#
# [160909 rows x 4 columns]

# %%
def plot_pos_vs_neg(df, intersect):
    data = df[df.q1_q2_intersect == intersect]
    pos_num = len(data[data['label'] == 1])
    neg_num = len(data[data['label'] == 0])
    plt.bar(['pos', 'neg'], [pos_num, neg_num])
    return pos_num, neg_num

# %%
plot_pos_vs_neg(kn_pairs_sampled_test, 0)
# Out:
# (10740, 25061)

# %%
plot_pos_vs_neg(kn_pairs_sampled_test, 1)
# Out:
# (973, 2270)

# %%
plot_pos_vs_neg(kn_pairs_sampled_test, 2)
# Out:
# (14, 33)

# %%
plot_pos_vs_neg(kn_pairs_sampled_test, 3)
# Out:
# (0, 0)

# %%
plot_pos_vs_neg(kn_pairs_sampled_test, 4)
# Out:
# (0, 0)

# %%
temp = kn_pairs_sampled[kn_pairs_sampled['q1_q2_intersect']==2]

# %%
temp.shape
# Out:
# (3279, 4)

# %%
temp[temp.label == 1].shape, temp[temp.label == 0].shape
# Out:
# ((3213, 4), (66, 4))

# %%
plot_pos_vs_neg(kn_pairs_sampled_train, 0)
# Out:
# (32397, 110814)

# %%
plot_pos_vs_neg(kn_pairs_sampled_train, 1)
# Out:
# (11186, 1788)

# %%
plot_pos_vs_neg(kn_pairs_sampled_train, 2)
# Out:
# (3199, 33)

# %%
plot_pos_vs_neg(kn_pairs_sampled_train, 3)
# Out:
# (945, 1)

# %%
plot_pos_vs_neg(kn_pairs_sampled_train, 4)
# Out:
# (369, 0)

# %%
plot_pos_vs_neg(kn_pairs_sampled_train, 5)
# Out:
# (121, 0)

# %%
(kn_pairs_sampled_train['label'] == 1).sum(), (kn_pairs_sampled_train['label'] == 1).sum() / ((kn_pairs_sampled_train['label'] == 1).sum() + (kn_pairs_sampled_train['label'] == 0).sum())
# Out:
# (48273, 0.300001864407833)

# %%
kn_pairs_sampled_train
# Out:
#         label       q1       q2  q1_q2_intersect
# 0           1  Q551771  Q519781                0
# 1           1  Q159309  Q275150                0
# 2           1  Q273703  Q455983                0
# 3           1  Q251674  Q693113                0
# 4           1  Q356129  Q636895                0
# 5           1  Q032964  Q427901                0
# 6           1  Q725121  Q061195                0
# 7           1  Q722645  Q681563                0
# 8           1  Q642737  Q590544                0
# 9           1  Q066508  Q573688                0
# 10          1  Q456113  Q480142                0
# 11          1  Q028018  Q444976                0
# 12          1  Q580970  Q021315                0
# 13          1  Q285073  Q428275                0
# 14          1  Q392078  Q033290                0
# 15          1  Q190463  Q315679                0
# 16          1  Q503854  Q529423                0
# 17          1  Q665030  Q375924                0
# 18          1  Q181087  Q283928                0
# 19          1  Q167355  Q624931                0
# 20          1  Q448950  Q565861                0
# 21          1  Q447582  Q199547                0
# 22          1  Q080422  Q074582                0
# 23          1  Q726508  Q100099                0
# 24          1  Q425630  Q505409                0
# 25          1  Q724991  Q374285                0
# 26          1  Q465993  Q180517                0
# 27          1  Q714440  Q399469                0
# 28          1  Q632956  Q100099                0
# 29          1  Q556729  Q056824                0
# ...       ...      ...      ...              ...
# 160879      1  Q724628  Q621258                6
# 160880      1  Q142598  Q348862                6
# 160881      1  Q339303  Q139612                6
# 160882      1  Q595401  Q424359                6
# 160883      1  Q714501  Q397345                6
# 160884      1  Q552953  Q581811                6
# 160885      1  Q661937  Q336995                6
# 160886      1  Q654197  Q452416                6
# 160887      1  Q180060  Q512266                6
# 160888      1  Q685446  Q520567                6
# 160889      1  Q339303  Q066137                6
# 160890      1  Q414588  Q127141                6
# 160891      1  Q473488  Q173464                6
# 160892      1  Q269490  Q185442                6
# 160893      1  Q244746  Q583345                7
# 160894      1  Q390548  Q660889                7
# 160895      1  Q255389  Q578889                7
# 160896      1  Q091001  Q328268                7
# 160897      1  Q697402  Q421188                7
# 160898      1  Q555455  Q225809                7
# 160899      1  Q067269  Q133646                7
# 160900      1  Q715144  Q062356                7
# 160901      1  Q493240  Q562867                7
# 160902      1  Q665518  Q026923                7
# 160903      1  Q066137  Q646250                7
# 160904      1  Q583345  Q097947                7
# 160905      1  Q328268  Q305794                8
# 160906      1  Q644268  Q225809                8
# 160907      1  Q442262  Q076902                8
# 160908      1  Q380993  Q615659                8
#
# [160909 rows x 4 columns]

# %%
KN_PAIRS_SAMPLED_TRAIN_CSV = os.path.join(DATA_SET_PATH, 'intermediate/kn_pairs_sampled_train.csv')
KN_PAIRS_SAMPLED_TEST_CSV = os.path.join(DATA_SET_PATH, 'intermediate/kn_pairs_sampled_test.csv')
kn_pairs_sampled_train.to_csv(KN_PAIRS_SAMPLED_TRAIN_CSV, index=False)
kn_pairs_sampled_test.to_csv(KN_PAIRS_SAMPLED_TEST_CSV, index=False)
